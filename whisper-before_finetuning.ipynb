# %% [markdown]
# # 집중해조
# : 2024-2 이화여자대학교 휴먼기계바이오공학부 융합캡스톤

# %% [markdown]
# ## before fine-tuning

# %% [markdown]
# ### some lectures test

# %% [markdown]
# - random test : arch, comp, elec, huma, lang 5개의 과목에 대해 랜덤으로 5개의 강의 테스트
# - selected lecture
#     - 'arch\\C06613', 'arch\\C01748', 'arch\\C02799', 'arch\\C04157', arch\\C04006'
#     - 'comp\\C08360', 'comp\\C08367', 'comp\\C07447', 'comp\\C12319', 'comp\\C05378'
#     - 'elec\\C02824', 'elec\\C06168', 'elec\\C02727', 'elec\\C13269', 'elec\\C02689'
#     - 'huma\\C00537', 'huma\\C01442', 'huma\\C13960', 'huma\\C07347', 'huma\\C04142'
#     - 'lang\\C03841', 'lang\\C10365', 'lang\\C13586', 'lang\\C05227', 'lang\\C03843'

# %%
import os
import glob

def find_all_lecture_files(source_dir, label_dir):
    """
    디렉토리 전체를 탐색하여 모든 강의의 wav 파일과 json 파일을 찾습니다.
    source_dir: wav 파일 경로가 있는 루트 디렉토리
    label_dir: json 파일 경로가 있는 루트 디렉토리
    """
    all_wav_files = []
    all_json_files = []
    
    # 디렉토리 전체 탐색
    for root, dirs, files in os.walk(source_dir):
        for file in files:
            if file.endswith(".wav"):  # WAV 파일 찾기
                # wav 파일 경로
                wav_path = os.path.join(root, file)
                
                # 해당 wav 파일에 대응하는 json 파일 경로 생성
                relative_path = os.path.relpath(wav_path, source_dir)
                json_path = os.path.join(label_dir, relative_path).replace(".wav", ".json")
                
                # json 파일이 존재하면 리스트에 추가
                if os.path.exists(json_path):
                    all_wav_files.append(wav_path)
                    all_json_files.append(json_path)
    
    return all_wav_files, all_json_files

# 루트 디렉토리 경로 설정
source_dir = "test/source"
label_dir = "test/labels"

# 모든 강의 파일 탐색
wav_files, json_files = find_all_lecture_files(source_dir, label_dir)

print("Total WAV Files: ", len(wav_files))
print("Total JSON Files: ", len(json_files))
# Out:
# Total WAV Files:  71652
# Total JSON Files:  71652

# %%
import os
import json
import random
import torch
from datasets import Dataset
from transformers import pipeline
from jiwer import wer

# 디바이스 설정 (GPU 사용 가능 시 GPU로 설정)
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Device: {device}")

# Whisper 모델 로드
pipe = pipeline(
    task="automatic-speech-recognition",
    model="openai/whisper-medium",
    device=0 if device == "cuda" else -1,
    return_timestamps=True
)

# 랜덤으로 5개의 강의 디렉토리 선택 함수
def get_random_lectures(root_dir, subdirs, num_samples=5):
    """
    각 하위 디렉토리(subdirs)에서 랜덤으로 num_samples만큼 강의를 선택.
    """
    selected_lectures = []
    for subdir in subdirs:
        lecture_path = os.path.join(root_dir, subdir)
        if os.path.exists(lecture_path):
            # 강의 디렉토리들 가져오기
            lectures = [os.path.join(lecture_path, d) for d in os.listdir(lecture_path) if os.path.isdir(os.path.join(lecture_path, d))]
            # 랜덤으로 num_samples만큼 선택
            selected_lectures.extend(random.sample(lectures, min(num_samples, len(lectures))))
    return selected_lectures

# 강의 디렉토리 루트 설정
source_root = "test/source"
label_root = "test/labels"
categories = ["eng/arch", "eng/comp", "eng/elec", "hum/huma", "hum/lang"]

# 랜덤으로 5개의 강의 선택
selected_lectures = get_random_lectures(source_root, categories, num_samples=5)
print("Selected Lectures:", selected_lectures)

# 선택된 강의에서 wav와 json 파일 수집
wav_files = []
json_files = []
for lecture in selected_lectures:
    for wav_file in glob.glob(os.path.join(lecture, "*.wav")):
        # JSON 파일 경로 생성
        relative_path = os.path.relpath(wav_file, source_root)
        json_file = os.path.join(label_root, relative_path).replace(".wav", ".json")
        if os.path.exists(json_file):
            wav_files.append(wav_file)
            json_files.append(json_file)

print(f"Total WAV Files: {len(wav_files)}, Total JSON Files: {len(json_files)}")

# ASR 수행 및 평가: Hugging Face Datasets 활용
if len(wav_files) > 0:
    # 데이터셋 생성
    data = Dataset.from_dict({"audio": wav_files})

    # ASR 수행
    asr_results = pipe(data["audio"])  # Whisper 모델로 일괄 처리

    # 평가 결과 저장
    evaluation_results = []
    for wav_file, json_file, asr_result in zip(wav_files, json_files, asr_results):
        # 라벨 데이터 로드
        with open(json_file, 'r', encoding='utf-8') as f:
            label_data = json.load(f)
            label_text = label_data["06_transcription"]["1_text"]

        # WER 계산
        error_rate = wer(label_text, asr_result["text"])

        # 결과 저장
        evaluation_results.append({
            "wav_file": wav_file,
            "json_file": json_file,
            "asr_text": asr_result["text"],
            "label_text": label_text,
            "wer": error_rate
        })

    # 평균 WER 계산
    average_wer = sum(result["wer"] for result in evaluation_results) / len(evaluation_results)

    # 결과 저장
    output_data = {
        "evaluation_results": evaluation_results,
        "average_wer": average_wer
    }
    output_file = "random_evaluation_results.json"
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(output_data, f, ensure_ascii=False, indent=4)

    print(f"Random evaluation results saved to {output_file}")
else:
    print("No files found for processing.")
# Out:
# Device: cuda
# Selected Lectures: ['test/source\\eng/arch\\C06613', 'test/source\\eng/arch\\C01748', 'test/source\\eng/arch\\C02799', 'test/source\\eng/arch\\C04157', 'test/source\\eng/arch\\C04006', 'test/source\\eng/comp\\C08360', 'test/source\\eng/comp\\C08367', 'test/source\\eng/comp\\C07447', 'test/source\\eng/comp\\C12319', 'test/source\\eng/comp\\C05378', 'test/source\\eng/elec\\C02824', 'test/source\\eng/elec\\C06168', 'test/source\\eng/elec\\C02727', 'test/source\\eng/elec\\C13269', 'test/source\\eng/elec\\C02689', 'test/source\\hum/huma\\C00537', 'test/source\\hum/huma\\C01442', 'test/source\\hum/huma\\C13960', 'test/source\\hum/huma\\C07347', 'test/source\\hum/huma\\C04142', 'test/source\\hum/lang\\C03841', 'test/source\\hum/lang\\C10365', 'test/source\\hum/lang\\C13586', 'test/source\\hum/lang\\C05227', 'test/source\\hum/lang\\C03843']
# c:\Users\yein\anaconda3\envs\cap\lib\site-packages\transformers\models\whisper\generation_whisper.py:509: FutureWarning: The input name `inputs` is deprecated. Please make sure to use `input_features` instead.
#   warnings.warn(
# Due to a bug fix in https://github.com/huggingface/transformers/pull/28687 transcription using a multilingual Whisper will default to language detection followed by transcription instead of translation to English.This might be a breaking change for your use case. If you want to instead always translate your audio to English, make sure to pass `language='en'`.
# Total WAV Files: 7858, Total JSON Files: 7858
# Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.43.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
#
01748\\U00031.wav': ' 영국의 사과나무에서 사과가 떨어지는 것을 보고 뉴턴의 제이법칙, 육단의 일법칙, 이법칙을 정리했죠.', 'test/source/eng/arch/C01748\\U00047.wav': ' 그러니까 이제 힘이 커질 때는 진량이 커지거나 진량이 커지거나 또는 가속도가 커지면 되겠습니다.', 'test/source/eng/arch/C01748\\U00048.wav': ' 가속도가 커지면 그러니까 우리가 이제 진량이 커진다는 것은 결국은 진량하고 우리 몸무게 무게죠.', 'test/source/eng/arch/C01748\\U00039.wav':  ...

# %%
import json

# 라벨 데이터를 로드하여 비교
evaluation_results = {}
for wav_file, json_file in zip(wav_files, json_files):
    with open(json_file, 'r', encoding='utf-8') as f:
        label_data = json.load(f)
        label_text = label_data["06_transcription"]["1_text"]
    
    asr_text = asr_results[wav_file]
    evaluation_results[wav_file] = {
        "asr_text": asr_text,
        "label_text": label_text
    }

# 결과 출력
for file, result in evaluation_results.items():
    print(f"\nFile: {file}")
    print(f"ASR: {result['asr_text']}")
    print(f"Label: {result['label_text']}")
# Out:
# File: test/source/eng/arch/C01748\U00000.wav
# ASR:  학생 여러분 안녕하십니까
# Label: 학생 여러분 안녕하십니까?
#
# File: test/source/eng/arch/C01748\U00001.wav
# ASR:  지금부터 정력학 1주 2차 시강이 시작하도록 하겠습니다.
# Label: 지금부터 정역학 1주 2차시 강의 시작하도록 하겠습니다.
#
# File: test/source/eng/arch/C01748\U00002.wav
# ASR:  이 시간에는 정력학에서 다루게 될 힘의 단위 가장 많이 나오는 게 힘이기 때문에 이 힘의 단위를 먼저 정리하고 그리고 난 다음에 1장부터 진도를 나가도록 하겠습니다.
# Label: 이 시간에는 이 정역학에서 다루게 될 힘의 단위 가장 많이 나오는 게 힘이기 때문에 힘의 단위를 한번 정리하고 그러고 난 다음에 1장부터 진도를 나가도록 하겠습니다.
#
# File: test/source/eng/arch/C01748\U00003.wav
# ASR:  정력학에서 사용하는 힘의 단위로는 우리가 힘 하면 뉴턴과 킬로그램이 떠오르게 됩니다.
# Label: 정역학에서 사용하는 힘의 단위로는 우리가 이제 힘 하면은 이제 뉴턴과 킬로그램이 떠오르게 됩니다.
#
# File: test/source/eng/arch/C01748\U00004.wav
# ASR:  여러분들이 이미 중학교 때, 고등학교 때, 뉴턴 이라고 하는 단위를 사용하셨을 거예요.
# Label: 여러분들이 이미 중학교 때나 고등학교 때 이 뉴턴이라고 하는 단위를 사용하셨을 거예요.
#
# File: test/source/eng/arch/C01748\U00005.wav
# ASR:  그러나 우리가 실생활에서는 유턴을 잘 사용하지 않죠.
# Label: 그러나 우리가 실생활에서는 뉴턴을 잘 사용하지 않죠?
#
# File: test/source/eng/arch/C01748\U00006.wav
# ASR:  실생활에서는 뭘 씁니까?
# Label: 실생활에서는 뭘 씁니까?
#
# File: test/source/eng/arch/C01748\U00007.wav
# ASR:  킬로그램을 많이 씁니다.
# Label: 킬로그램을 많이 씁니다.
#
# File: test/source/eng/arch/C01748\U00008.wav
# ASR:  맞습니다.
# Label: 맞습니다.
#
# File: test/source/eng/arch/C01748\U00009.wav
# ASR:  이 정력화학에서도 일부 키로그램을 쓰는 교제가 있긴 합니다만 대부분 교제는 이 SI 단이라고 하죠.
# Label: 이 정역학에서도 일부 킬로그램을 쓰는 교재가 있긴 합니다만 대부분 교재는 이 에스아이 단위라고 그러죠?
#
# File: test/source/eng/arch/C01748\U00010.wav
# ASR:  SI단위, 힘에 관한 SI단위는 뉴턴이고, kg은 중력단위라고 하는데요.
# Label: 에스아이에 단위는 힘에 관한 에스아이의 단위는 뉴턴이고 킬로그램은 이제 중력단위라고 하는데요.
#
# File: test/source/eng/arch/C01748\U00011.wav
# ASR:  mks 단위라고 하였고 중낙단위라고 하는데 이 kg은 안쓰고 뉴톤을 사용합니다
# Label: 엠케이에스 단위라고 해갖고 중력단위라고 하는데 이 킬로그램을 안 쓰고 이 뉴턴을 사용합니다.
#
# File: test/source/eng/arch/C01748\U00012.wav
# ASR:  앞으로 흰 맘에는 뉴톤을 떠올리시기 바랍니다.
# Label: 앞으로는 이제 힘하면은 그러면 뉴턴을 떠올리시기 바랍니다.
#
# File: test/source/eng/arch/C01748\U00013.wav
# ASR:  그래서 이제 여기 정력화에 의해서는 힘이랄지 또는 중량 하중 부하 이런 것들이 이제 전부 힘에 다닌 유턴을 씁니다
# Label: 뉴턴을 사용한다니까 자 그래서 이제 여기 정역학에서는 힘이랄지 또는 중량 하중 부화 이런 것들이 이제 전부 이 힘의 단위 뉴턴을 씁니다.
#
# File: test/source/eng/arch/C01748\U00014.wav
# ASR:  힘 하면 우리가 force 해가지고 약간 물리적인 의미를 많이 담고 있는데요.
# Label: 이제 힘 하면은 우리가 포스해가지고 약간 이제 물리적인 의미를 많이 담고 있는데요.
#
# File: test/source/eng/arch/C01748\U00015.wav
# ASR:  이 힘이 공학적으로 사용하게 되면 중량, 웨이트가 되겠습니다.
# Label: 이 힘이 이제 공학적으로 사용하게 되면 중량 이거로는 웨이트가 되겠습니다.
#
# File: test/source/eng/arch/C01748\U00016.wav
# ASR:  그 다음에 하중이나 부하는 이제 로드가 되겠습니다.
# Label: 웨이트 그다음에 하중이나 부하은 로드가 되겠습니다.
#
# File: test/source/eng/arch/C01748\U00017.wav
# ASR:  중량은 우리 이제 무슨 몸무게 같이 무게 웨이트 몸무게처럼 그냥 무게에 가는 거구요
# Label: 로드 로드 중량은 우리 이제 무슨 몸무게 같이 무게 웨이트 몸무게처럼 그냥 무게에 관한 거고요.
#
# File: test/source/eng/arch/C01748\U00018.wav
# ASR:  하중이나 부하는 무게 개념이 아니고 외력이 가해지는 그런게 되겠습니다.
# Label: 이제 하중이나 부하는 무게 개념이 아니고 어떤 외력이 가해지는 그런 게 되겠습니다.
#
# File: test/source/eng/arch/C01748\U00019.wav
# ASR:  매력이 가해지는 그런 의미 되겠습니다.
# Label: 외력이 가해지는 그런 힘이 되겠습니다.
#
# File: test/source/eng/arch/C01748\U00020.wav
# ASR:  가령 예를 들면 비행기가 지상에서 정지하고 있다가 시속 100km 200km 300km 빨리 속도 나르면 양력이 생기죠.
# Label: 가령 예를 들면은 비행기가 지상에서 정지하고 있다가 시속 100킬로 200백킬로 300킬로 빨리 속도가 날으면은 양력이 생기죠.
#
# File: test/source/eng/arch/C01748\U00021.wav
# ASR:  양력은 중요하지 않습니다.
# Label: 양력 근데 양력은 중량이 아니죠?
#
# File: test/source/eng/arch/C01748\U00022.wav
# ASR:  양력에 의해서 비행기가 뜨잖아요.
# Label: 그 양력에 의해서 비행기가 뜨잖아요?
#
# File: test/source/eng/arch/C01748\U00023.wav
# ASR:  비행기를 뜨게 하기 위해서 공기가 하늘 방향으로 떠받치는 힘, 이게 양력인데 이런 양력들이 우리가 하중 부하 이렇게 이야기합니다.
# Label: 그 비행기를 뜨게 하기 위해서 공기가 이 하늘 방향으로 떠받치는 힘 이게 양력인데 이런 양력들이 우리가 이제 하중 부하 이렇게 이야기합니다.
#
# File: test/source/eng/arch/C01748\U00024.wav
# ASR:  보드라고 합니다.
# Label: 로드라고 합니다.
#
# File: test/source/eng/arch/C01748\U00025.wav
# ASR:  그런데 뭐 자동차가 도로 위에 서 있을 경우는 자동차 무게가 있죠
# Label: 로드 그런데 자동차가 도로 위에 서 있을 경우는 자동차 무게가 있죠?
#
# File: test/source/eng/arch/C01748\U00026.wav
# ASR:  그것을 무게 또는 중량 이렇게 이야기를 합니다.
# Label: 그것은 무게 또는 중량 이렇게 이야기를 합니다.
#
# File: test/source/eng/arch/C01748\U00027.wav
# ASR:  똑같은 개념이면 약간씩 달라요.
# Label: 똑같은 개념이지만은 약간 약간씩은 달라요.
#
# File: test/source/eng/arch/C01748\U00028.wav
# ASR:  그냥 뭐.. 이건 이제 언어의 뉘앙스의 차이기 때문에 크게 신경 안 쓰셔도 되겠습니다.
# Label: 그냥 이거 이제 언어의 뉘앙스의 차이기 때문에 크게 신경 안 쓰셔도 되겠습니다.
#
# File: test/source/eng/arch/C01748\U00029.wav
# ASR:  그러면 도대체 이 유턴이라는 게 뭔가 유턴이라는 게 뭔가에 대해서 지금부터 살펴보겠습니다.
# Label: 자 그러면은 도대체 이 뉴턴이라는 게 뭔가 뉴턴이라는게 뭔가에 대해서 지금부터 살펴보겠습니다.
#
# File: test/source/eng/arch/C01748\U00030.wav
# ASR:  네, 뉴턴은 이제 영어 대문자 N을 이렇게 쓰게 되는데 이 뉴턴은 우리가 알고 있는 뉴턴 있죠.
# Label: 뉴턴은 이제 영어 대문자 엔을 이렇게 쓰게 되는데 이 뉴턴은 우리가 알고 있는 이 뉴턴 있죠.
#
# File: test/source/eng/arch/C01748\U00031.wav
# ASR:  영국의 사과나무에서 사과가 떨어지는 것을 보고 뉴턴의 제이법칙, 육단의 일법칙, 이법칙을 정리했죠.
# Label: 아이작 뉴턴 영국의 에 사과나무에서 사과가 떨어지는 것을 보고 뉴턴의 제2법칙 뉴턴의 1법칙 2법칙을 정리를 했죠?
#
# File: test/source/eng/arch/C01748\U00032.wav
# ASR:  거기서 이제 우리가 이 기계에서 또 물리에서 가장 많이 사용하는 법칙이 제2 법칙입니다.
# Label: 거기서 이제 우리가 이 기계에서 또 물리에서 가장 많이 사용하는 법칙이 제 2법칙입니다.
#
# File: test/source/eng/arch/C01748\U00033.wav
# ASR:  힘과 가속도 법칙 그래서 힘은 MA이다.
# Label: 힘과 과속도 법칙 힘은 엠에이다.
#
# File: test/source/eng/arch/C01748\U00034.wav
# ASR:  하지만 진량 곱하기 가속도 이렇게 됩니다.
# Label: 힘은 질량 곱하기 가속도 이렇게 됩니다.
#
# File: test/source/eng/arch/C01748\U00035.wav
# ASR:  보통 물체가 움직이거나 진량은 변하지 않고, 가속도가 변함에 따라서 힘이 생기게 됩니다.
# Label: 그게 이제 보통 물체가 움직이거나 그러면 질량은 변하지가 않고 이제 주로 가속도가 변함에 따라서 이제 이 힘이 생기게 됩니다.
#
# File: test/source/eng/arch/C01748\U00036.wav
# ASR:  그래서 F는 힘이구요
# Label: 그래서 에프는 힘이고요.
#
# File: test/source/eng/arch/C01748\U00037.wav
# ASR:  m은 진량, 영어로 mess라고 하죠
# Label: 엠은 질량 영어로 메스라고 그러죠?
#
# File: test/source/eng/arch/C01748\U00038.wav
# ASR:  a는 가속도가 되겠습니다
# Label: 에이는 가속도가 되겠습니다.
#
# File: test/source/eng/arch/C01748\U00039.wav
# ASR:  그래서 유턴제 2법치기 F equal MA인데 이 F equal MA에 따르면 진량 1kgm가 가속도 1mps의 가속도를 받을 때 힘을 받게 되는데 이 힘을 1Utn으로 정해 한다.
# Label: 에이는 가속도 그래서 뉴턴 제 2 법칙이 에프 이코르 엠에이인데 이 에프 이코르 엠에이에 따르면 질량 1킬로그램 매스가 질량 1킬로그램 매스가 가속도 1메타퍼 세크의 가속도를 받을 때 힘을 이제 받게 되는데 이 힘을 1 뉴턴으로 정의한다 그렇습니다.
#
# File: test/source/eng/arch/C01748\U00040.wav
# ASR:  이녀석
# Label: 정의한다.
#
# File: test/source/eng/arch/C01748\U00041.wav
# ASR:  그래서 1kgm에다가 1m% 제곱을 뉴턴 제입업적에 따라서 곱해요.
# Label: 그래서 1킬로그램 매스했다가 일 메타 퍼 세크 제곱을 뉴턴 제 2 법칙 따라서 곱해요.
#
# File: test/source/eng/arch/C01748\U00042.wav
# ASR:  곱해면 숫자끼리 곱하면 1이 되구요
# Label: 곱하면 숫자끼리 곱하면은 1이 되고요.
#
# File: test/source/eng/arch/C01748\U00043.wav
# ASR:  이 단위를 전부 곱합니다. 그럼 kg에다가 써주고, meta에다가 써주고요
# Label: 그러면 킬로그램 여기다 써주고 메타 여기다가 써주고요.
#
# File: test/source/eng/arch/C01748\U00044.wav
# ASR:  그 다음에 세크의 제거에 있다가 써주게 되죠
# Label: 그다음에 세크의 제곱 여기다가 써주게 되죠.
#
# File: test/source/eng/arch/C01748\U00045.wav
# ASR:  킬로그램 메스 메타퍼세크의 제곱이 되는데 이게 단위가 이제 이게 이제 힘의 단위가 되는데 진량하고 과적도 곱했으니까 이게 힘이죠. 힘인데 이것을 복잡하니까 이것을 따로 그냥 다른 기어로 하나 정해놓자. 그 한개 바로 n으로 쓰고 newton으로 있게 되겠습니다.
# Label: 그러면 킬로그램 매스 메타 퍼 세크에 제곱이 되는데 이게 단위가 이제 힘의 단위가 되는데 질량하고 가속도 곱했으니까 이게 힘이죠 힘인데 이것을 복잡하니까 이것을 따로 그냥 다른 기호로 하나 정해놓자고한 게 바로 엔 쓰고 뉴턴으로 읽게 되겠습니다.
#
# File: test/source/eng/arch/C01748\U00046.wav
# ASR:  이게 1유턴이 되겠습니다.
# Label: 이게 1뉴턴이 되겠습니다.
#
# File: test/source/eng/arch/C01748\U00047.wav
# ASR:  그러니까 이제 힘이 커질 때는 진량이 커지거나 진량이 커지거나 또는 가속도가 커지면 되겠습니다.
# Label: 그러니까 이제 힘이 커질 때는 질량이 커지거나 또는 가속도가 커지면 되겠습니다.
#
# File: test/source/eng/arch/C01748\U00048.wav
# ASR:  가속도가 커지면 그러니까 우리가 이제 진량이 커진다는 것은 결국은 진량하고 우리 몸무게 무게죠.
# Label: 가속도가 커지면 그러니까 우리가 이제 질량이 커진다는 거는 결국은 질량하고 무게죠.
#
# File: test/source/eng/arch/C01748\U00049.wav
# ASR:  중량하고는 사실 지구에서는 구분하지 않고 쓰거든요.
# Label: 중량하고는 사실 이제 지구에서는 구분하지 않고 쓰거든요.

# %%
from jiwer import wer

# WER 계산
for file, result in evaluation_results.items():
    asr_text = result["asr_text"]
    label_text = result["label_text"]
    error_rate = wer(label_text, asr_text)
    evaluation_results[file]["wer"] = error_rate

# 결과 출력
for file, result in evaluation_results.items():
    print(f"\nFile: {file}")
    print(f"ASR: {result['asr_text']}")
    print(f"Label: {result['label_text']}")
    print(f"WER: {result['wer']}")
# Out:
# File: test/source/eng/arch/C01748\U00000.wav
# ASR:  학생 여러분 안녕하십니까
# Label: 학생 여러분 안녕하십니까?
# WER: 0.3333333333333333
#
# File: test/source/eng/arch/C01748\U00001.wav
# ASR:  지금부터 정력학 1주 2차 시강이 시작하도록 하겠습니다.
# Label: 지금부터 정역학 1주 2차시 강의 시작하도록 하겠습니다.
# WER: 0.42857142857142855
#
# File: test/source/eng/arch/C01748\U00002.wav
# ASR:  이 시간에는 정력학에서 다루게 될 힘의 단위 가장 많이 나오는 게 힘이기 때문에 이 힘의 단위를 먼저 정리하고 그리고 난 다음에 1장부터 진도를 나가도록 하겠습니다.
# Label: 이 시간에는 이 정역학에서 다루게 될 힘의 단위 가장 많이 나오는 게 힘이기 때문에 힘의 단위를 한번 정리하고 그러고 난 다음에 1장부터 진도를 나가도록 하겠습니다.
# WER: 0.2
#
# File: test/source/eng/arch/C01748\U00003.wav
# ASR:  정력학에서 사용하는 힘의 단위로는 우리가 힘 하면 뉴턴과 킬로그램이 떠오르게 됩니다.
# Label: 정역학에서 사용하는 힘의 단위로는 우리가 이제 힘 하면은 이제 뉴턴과 킬로그램이 떠오르게 됩니다.
# WER: 0.3076923076923077
#
# File: test/source/eng/arch/C01748\U00004.wav
# ASR:  여러분들이 이미 중학교 때, 고등학교 때, 뉴턴 이라고 하는 단위를 사용하셨을 거예요.
# Label: 여러분들이 이미 중학교 때나 고등학교 때 이 뉴턴이라고 하는 단위를 사용하셨을 거예요.
# WER: 0.3333333333333333
#
# File: test/source/eng/arch/C01748\U00005.wav
# ASR:  그러나 우리가 실생활에서는 유턴을 잘 사용하지 않죠.
# Label: 그러나 우리가 실생활에서는 뉴턴을 잘 사용하지 않죠?
# WER: 0.2857142857142857
#
# File: test/source/eng/arch/C01748\U00006.wav
# ASR:  실생활에서는 뭘 씁니까?
# Label: 실생활에서는 뭘 씁니까?
# WER: 0.0
#
# File: test/source/eng/arch/C01748\U00007.wav
# ASR:  킬로그램을 많이 씁니다.
# Label: 킬로그램을 많이 씁니다.
# WER: 0.0
#
# File: test/source/eng/arch/C01748\U00008.wav
# ASR:  맞습니다.
# Label: 맞습니다.
# WER: 0.0
#
# File: test/source/eng/arch/C01748\U00009.wav
# ASR:  이 정력화학에서도 일부 키로그램을 쓰는 교제가 있긴 합니다만 대부분 교제는 이 SI 단이라고 하죠.
# Label: 이 정역학에서도 일부 킬로그램을 쓰는 교재가 있긴 합니다만 대부분 교재는 이 에스아이 단위라고 그러죠?
# WER: 0.5
#
# File: test/source/eng/arch/C01748\U00010.wav
# ASR:  SI단위, 힘에 관한 SI단위는 뉴턴이고, kg은 중력단위라고 하는데요.
# Label: 에스아이에 단위는 힘에 관한 에스아이의 단위는 뉴턴이고 킬로그램은 이제 중력단위라고 하는데요.
# WER: 0.6363636363636364
#
# File: test/source/eng/arch/C01748\U00011.wav
# ASR:  mks 단위라고 하였고 중낙단위라고 하는데 이 kg은 안쓰고 뉴톤을 사용합니다
# Label: 엠케이에스 단위라고 해갖고 중력단위라고 하는데 이 킬로그램을 안 쓰고 이 뉴턴을 사용합니다.
# WER: 0.75
#
# File: test/source/eng/arch/C01748\U00012.wav
# ASR:  앞으로 흰 맘에는 뉴톤을 떠올리시기 바랍니다.
# Label: 앞으로는 이제 힘하면은 그러면 뉴턴을 떠올리시기 바랍니다.
# WER: 0.7142857142857143
#
# File: test/source/eng/arch/C01748\U00013.wav
# ASR:  그래서 이제 여기 정력화에 의해서는 힘이랄지 또는 중량 하중 부하 이런 것들이 이제 전부 힘에 다닌 유턴을 씁니다
# Label: 뉴턴을 사용한다니까 자 그래서 이제 여기 정역학에서는 힘이랄지 또는 중량 하중 부화 이런 것들이 이제 전부 이 힘의 단위 뉴턴을 씁니다.
# WER: 0.5238095238095238
#
# File: test/source/eng/arch/C01748\U00014.wav
# ASR:  힘 하면 우리가 force 해가지고 약간 물리적인 의미를 많이 담고 있는데요.
# Label: 이제 힘 하면은 우리가 포스해가지고 약간 이제 물리적인 의미를 많이 담고 있는데요.
# WER: 0.4166666666666667
#
# File: test/source/eng/arch/C01748\U00015.wav
# ASR:  이 힘이 공학적으로 사용하게 되면 중량, 웨이트가 되겠습니다.
# Label: 이 힘이 이제 공학적으로 사용하게 되면 중량 이거로는 웨이트가 되겠습니다.
# WER: 0.3
#
# File: test/source/eng/arch/C01748\U00016.wav
# ASR:  그 다음에 하중이나 부하는 이제 로드가 되겠습니다.
# Label: 웨이트 그다음에 하중이나 부하은 로드가 되겠습니다.
# WER: 0.6666666666666666
#
# File: test/source/eng/arch/C01748\U00017.wav
# ASR:  중량은 우리 이제 무슨 몸무게 같이 무게 웨이트 몸무게처럼 그냥 무게에 가는 거구요
# Label: 로드 로드 중량은 우리 이제 무슨 몸무게 같이 무게 웨이트 몸무게처럼 그냥 무게에 관한 거고요.
# WER: 0.26666666666666666
#
# File: test/source/eng/arch/C01748\U00018.wav
# ASR:  하중이나 부하는 무게 개념이 아니고 외력이 가해지는 그런게 되겠습니다.
# Label: 이제 하중이나 부하는 무게 개념이 아니고 어떤 외력이 가해지는 그런 게 되겠습니다.
# WER: 0.3333333333333333
#
# File: test/source/eng/arch/C01748\U00019.wav
# ASR:  매력이 가해지는 그런 의미 되겠습니다.
# Label: 외력이 가해지는 그런 힘이 되겠습니다.
# WER: 0.4
#
# File: test/source/eng/arch/C01748\U00020.wav
# ASR:  가령 예를 들면 비행기가 지상에서 정지하고 있다가 시속 100km 200km 300km 빨리 속도 나르면 양력이 생기죠.
# Label: 가령 예를 들면은 비행기가 지상에서 정지하고 있다가 시속 100킬로 200백킬로 300킬로 빨리 속도가 날으면은 양력이 생기죠.
# WER: 0.375
#
# File: test/source/eng/arch/C01748\U00021.wav
# ASR:  양력은 중요하지 않습니다.
# Label: 양력 근데 양력은 중량이 아니죠?
# WER: 0.8
#
# File: test/source/eng/arch/C01748\U00022.wav
# ASR:  양력에 의해서 비행기가 뜨잖아요.
# Label: 그 양력에 의해서 비행기가 뜨잖아요?
# WER: 0.4
#
# File: test/source/eng/arch/C01748\U00023.wav
# ASR:  비행기를 뜨게 하기 위해서 공기가 하늘 방향으로 떠받치는 힘, 이게 양력인데 이런 양력들이 우리가 하중 부하 이렇게 이야기합니다.
# Label: 그 비행기를 뜨게 하기 위해서 공기가 이 하늘 방향으로 떠받치는 힘 이게 양력인데 이런 양력들이 우리가 이제 하중 부하 이렇게 이야기합니다.
# WER: 0.19047619047619047
#
# File: test/source/eng/arch/C01748\U00024.wav
# ASR:  보드라고 합니다.
# Label: 로드라고 합니다.
# WER: 0.5
#
# File: test/source/eng/arch/C01748\U00025.wav
# ASR:  그런데 뭐 자동차가 도로 위에 서 있을 경우는 자동차 무게가 있죠
# Label: 로드 그런데 자동차가 도로 위에 서 있을 경우는 자동차 무게가 있죠?
# WER: 0.2727272727272727
#
# File: test/source/eng/arch/C01748\U00026.wav
# ASR:  그것을 무게 또는 중량 이렇게 이야기를 합니다.
# Label: 그것은 무게 또는 중량 이렇게 이야기를 합니다.
# WER: 0.14285714285714285
#
# File: test/source/eng/arch/C01748\U00027.wav
# ASR:  똑같은 개념이면 약간씩 달라요.
# Label: 똑같은 개념이지만은 약간 약간씩은 달라요.
# WER: 0.6
#
# File: test/source/eng/arch/C01748\U00028.wav
# ASR:  그냥 뭐.. 이건 이제 언어의 뉘앙스의 차이기 때문에 크게 신경 안 쓰셔도 되겠습니다.
# Label: 그냥 이거 이제 언어의 뉘앙스의 차이기 때문에 크게 신경 안 쓰셔도 되겠습니다.
# WER: 0.16666666666666666
#
# File: test/source/eng/arch/C01748\U00029.wav
# ASR:  그러면 도대체 이 유턴이라는 게 뭔가 유턴이라는 게 뭔가에 대해서 지금부터 살펴보겠습니다.
# Label: 자 그러면은 도대체 이 뉴턴이라는 게 뭔가 뉴턴이라는게 뭔가에 대해서 지금부터 살펴보겠습니다.
# WER: 0.4166666666666667
#
# File: test/source/eng/arch/C01748\U00030.wav
# ASR:  네, 뉴턴은 이제 영어 대문자 N을 이렇게 쓰게 되는데 이 뉴턴은 우리가 알고 있는 뉴턴 있죠.
# Label: 뉴턴은 이제 영어 대문자 엔을 이렇게 쓰게 되는데 이 뉴턴은 우리가 알고 있는 이 뉴턴 있죠.
# WER: 0.1875
#
# File: test/source/eng/arch/C01748\U00031.wav
# ASR:  영국의 사과나무에서 사과가 떨어지는 것을 보고 뉴턴의 제이법칙, 육단의 일법칙, 이법칙을 정리했죠.
# Label: 아이작 뉴턴 영국의 에 사과나무에서 사과가 떨어지는 것을 보고 뉴턴의 제2법칙 뉴턴의 1법칙 2법칙을 정리를 했죠?
# WER: 0.5625
#
# File: test/source/eng/arch/C01748\U00032.wav
# ASR:  거기서 이제 우리가 이 기계에서 또 물리에서 가장 많이 사용하는 법칙이 제2 법칙입니다.
# Label: 거기서 이제 우리가 이 기계에서 또 물리에서 가장 많이 사용하는 법칙이 제 2법칙입니다.
# WER: 0.15384615384615385
#
# File: test/source/eng/arch/C01748\U00033.wav
# ASR:  힘과 가속도 법칙 그래서 힘은 MA이다.
# Label: 힘과 과속도 법칙 힘은 엠에이다.
# WER: 0.6
#
# File: test/source/eng/arch/C01748\U00034.wav
# ASR:  하지만 진량 곱하기 가속도 이렇게 됩니다.
# Label: 힘은 질량 곱하기 가속도 이렇게 됩니다.
# WER: 0.3333333333333333
#
# File: test/source/eng/arch/C01748\U00035.wav
# ASR:  보통 물체가 움직이거나 진량은 변하지 않고, 가속도가 변함에 따라서 힘이 생기게 됩니다.
# Label: 그게 이제 보통 물체가 움직이거나 그러면 질량은 변하지가 않고 이제 주로 가속도가 변함에 따라서 이제 이 힘이 생기게 됩니다.
# WER: 0.5263157894736842
#
# File: test/source/eng/arch/C01748\U00036.wav
# ASR:  그래서 F는 힘이구요
# Label: 그래서 에프는 힘이고요.
# WER: 0.6666666666666666
#
# File: test/source/eng/arch/C01748\U00037.wav
# ASR:  m은 진량, 영어로 mess라고 하죠
# Label: 엠은 질량 영어로 메스라고 그러죠?
# WER: 0.8
#
# File: test/source/eng/arch/C01748\U00038.wav
# ASR:  a는 가속도가 되겠습니다
# Label: 에이는 가속도가 되겠습니다.
# WER: 0.6666666666666666
#
# File: test/source/eng/arch/C01748\U00039.wav
# ASR:  그래서 유턴제 2법치기 F equal MA인데 이 F equal MA에 따르면 진량 1kgm가 가속도 1mps의 가속도를 받을 때 힘을 받게 되는데 이 힘을 1Utn으로 정해 한다.
# Label: 에이는 가속도 그래서 뉴턴 제 2 법칙이 에프 이코르 엠에이인데 이 에프 이코르 엠에이에 따르면 질량 1킬로그램 매스가 질량 1킬로그램 매스가 가속도 1메타퍼 세크의 가속도를 받을 때 힘을 이제 받게 되는데 이 힘을 1 뉴턴으로 정의한다 그렇습니다.
# WER: 0.6756756756756757
#
# File: test/source/eng/arch/C01748\U00040.wav
# ASR:  이녀석
# Label: 정의한다.
# WER: 1.0
#
# File: test/source/eng/arch/C01748\U00041.wav
# ASR:  그래서 1kgm에다가 1m% 제곱을 뉴턴 제입업적에 따라서 곱해요.
# Label: 그래서 1킬로그램 매스했다가 일 메타 퍼 세크 제곱을 뉴턴 제 2 법칙 따라서 곱해요.
# WER: 0.6428571428571429
#
# File: test/source/eng/arch/C01748\U00042.wav
# ASR:  곱해면 숫자끼리 곱하면 1이 되구요
# Label: 곱하면 숫자끼리 곱하면은 1이 되고요.
# WER: 0.6
#
# File: test/source/eng/arch/C01748\U00043.wav
# ASR:  이 단위를 전부 곱합니다. 그럼 kg에다가 써주고, meta에다가 써주고요
# Label: 그러면 킬로그램 여기다 써주고 메타 여기다가 써주고요.
# WER: 1.2857142857142858
#
# File: test/source/eng/arch/C01748\U00044.wav
# ASR:  그 다음에 세크의 제거에 있다가 써주게 되죠
# Label: 그다음에 세크의 제곱 여기다가 써주게 되죠.
# WER: 0.8333333333333334
#
# File: test/source/eng/arch/C01748\U00045.wav
# ASR:  킬로그램 메스 메타퍼세크의 제곱이 되는데 이게 단위가 이제 이게 이제 힘의 단위가 되는데 진량하고 과적도 곱했으니까 이게 힘이죠. 힘인데 이것을 복잡하니까 이것을 따로 그냥 다른 기어로 하나 정해놓자. 그 한개 바로 n으로 쓰고 newton으로 있게 되겠습니다.
# Label: 그러면 킬로그램 매스 메타 퍼 세크에 제곱이 되는데 이게 단위가 이제 힘의 단위가 되는데 질량하고 가속도 곱했으니까 이게 힘이죠 힘인데 이것을 복잡하니까 이것을 따로 그냥 다른 기호로 하나 정해놓자고한 게 바로 엔 쓰고 뉴턴으로 읽게 되겠습니다.
# WER: 0.4722222222222222
#
# File: test/source/eng/arch/C01748\U00046.wav
# ASR:  이게 1유턴이 되겠습니다.
# Label: 이게 1뉴턴이 되겠습니다.
# WER: 0.3333333333333333
#
# File: test/source/eng/arch/C01748\U00047.wav
# ASR:  그러니까 이제 힘이 커질 때는 진량이 커지거나 진량이 커지거나 또는 가속도가 커지면 되겠습니다.
# Label: 그러니까 이제 힘이 커질 때는 질량이 커지거나 또는 가속도가 커지면 되겠습니다.
# WER: 0.2727272727272727
#
# File: test/source/eng/arch/C01748\U00048.wav
# ASR:  가속도가 커지면 그러니까 우리가 이제 진량이 커진다는 것은 결국은 진량하고 우리 몸무게 무게죠.
# Label: 가속도가 커지면 그러니까 우리가 이제 질량이 커진다는 거는 결국은 질량하고 무게죠.
# WER: 0.45454545454545453
#
# File: test/source/eng/arch/C01748\U00049.wav
# ASR:  중량하고는 사실 지구에서는 구분하지 않고 쓰거든요.
# Label: 중량하고는 사실 이제 지구에서는 구분하지 않고 쓰거든요.
# WER: 0.14285714285714285

# %%
# 전체 WER 평균 계산
total_wer = sum(result["wer"] for result in evaluation_results.values()) / len(evaluation_results)
print(f"Average WER for the lecture: {total_wer}")
# Out:
# Average WER for the lecture: 0.449418506181664
